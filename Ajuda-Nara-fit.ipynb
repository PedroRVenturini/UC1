# %% [markdown]
# ## Ajuda projeto final UC1

# %%
dicionario = {'Nome' :[],
              'Idade' :[],
              'Peso' :[],
              'Altura' :[]}

# %%
produtos = ['Tomate']   
print('#' * 20, 'BEM VINDO A NARA HORTI FRUTI', '#' * 20)

while True:
    print("1 - Adicionar item")
    print("2 - Listar itens")
    print("3 - Sair")
    opcao = int(input("Escolha uma opcao: "))

    if opcao == 1:
        escolha_produto = input('Digite o produto que deseja ').title()
        produtos.append(escolha_produto)
    elif opcao == 2:
        if len(produtos) == 0:
            print('Nenhum produto cadastrado') 
        else:
            for i in produtos:
                print(f'Produto {i}')
    elif opcao == 3:
        break
    else:
        print('Escolha uma opção válida')
# Out:
# #################### BEM VINDO A NARA HORTI FRUTI ####################
# 1 - Adicionar item
# 2 - Listar itens
# 3 - Sair
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 8
#       4 while True:
#       5     print("1 - Adicionar item")
#       6     print("2 - Listar itens")
#       7     print("3 - Sair")
# ----> 8     opcao = int(input("Escolha uma opcao: "))
#       9
#      10     if opcao == 1:
#      11         escolha_produto = input('Digite o produto que deseja ').title()
#
# ValueError: invalid literal for int() with base 10: ''
